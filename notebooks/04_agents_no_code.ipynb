# %% [markdown]
# # <span style="color:orange"> 4. No Code Agents (VS Code + Clien, GEMINI-CLI) </span>
#
# #####
#
# ## 4.2 Cline plug'in on VS Code
# #### Open VS code , Go to plug'ins  , search for Cline and install it

# %% [markdown]
# ![{FD4D4619-F047-4EA9-8E6A-8DE0599866F1}.png](attachment:e5c9bc58-72a4-477d-9edf-be464beb2a1e.png)

# %% [markdown]
# #### Next click on Cline then the config (gear) icon to add your API Keys
#
# ![{22CC3C23-3663-47E9-882A-F057FF537A2A}.png](attachment:4c135d6d-ac0a-4675-ab77-4faf38e20936.png)
#
# ####
#
# ![{A92AC48F-549F-4B5F-AB0A-DC5D8439EC88}.png](attachment:fb4cf65c-2e7a-492f-b951-44ee2e862681.png)
#
#
# ####
#
# ![{0FE36CE5-455F-4530-BBC6-7154A0A60751}.png](attachment:240d7536-cec7-4015-b453-cfa5d2bd9b68.png)
#
#
# #####
#
# ![{FEB9545B-93A2-4C5A-9024-5277216E0DFE}.png](attachment:a2b7f018-6752-4570-94fc-6e31e6261040.png)
#
# #####
#
# ![{406B5BAD-281E-40C6-89DB-4125D7CA144B}.png](attachment:4e5e363c-0211-4824-a49c-0a49032ae47b.png)

# %% [markdown]
# ![{371DFBA3-8CE6-4695-896B-983790EFC429}.png](attachment:f50e8b94-09da-4874-b1cc-435c27f467b5.png)

# %% [markdown]
# ## GEMINI-CLI
# ![{A91A584F-0A72-461B-A2D2-5D9777A7FCFC}.png](attachment:ee9d9867-f1c7-41e9-8bc0-d7eae1d48de0.png)
#
# ##### https://github.com/google-gemini/gemini-cli
# ![{503E1211-323D-47D4-9B77-F1295DD9FD91}.png](attachment:47ea89f2-c15c-4759-90d9-23f22ee7c3dc.png)

# %% [markdown]
# ##### npm install -g @google/gemini-cli
# ##### gemini
#
# ![image.png](attachment:00e9e9ae-1021-456a-8cec-08c533ce40ed.png)
#
# ![image.png](attachment:48e52983-36d2-44af-aec0-7fe24c974e14.png)
#
# ![image.png](attachment:0c7d26e2-539c-4911-ba18-047c0862b4bf.png)

# %% [markdown]
# #### You can now prompt for any action or build fromscratch, here a Conway game of life demo
#
# ![image.png](attachment:a25ffebf-3058-4d99-afcd-5d51bea2e9ac.png)
#
# #### You can allow always to change files
#
# ![image.png](attachment:81a59f5d-ecf8-4e11-8e53-2948862a70df.png)
#
# ![image.png](attachment:817766d2-eb62-4423-8e20-f361c70eee80.png)
