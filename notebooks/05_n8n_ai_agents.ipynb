# %% [markdown]
# # <span style="color:orange">  5. n8n workflows  </span>
#
# ##### https://n8n.io/
# #####
#
# ![{B6C1BF97-58F0-4C86-804C-F28DD1EE098A}.png](attachment:d832c58e-5d7b-400e-b9a9-740944ab67f3.png)

# %% [markdown]
# #### You can install a locally node on your VM or PC
# ####
# ![{40D19689-78AF-4457-A5D6-29836666FA46}.png](attachment:bc87041b-1f3e-40c6-9192-12ccd2d64b99.png)

# %% [markdown]
# #### Now go to http://localhost:5678/ and create an account to submit a free key licence for personal use
# #### When licence is received (email) and activated you can start creating your workflows
# ####
# #### In this tutorial we will work with the native AI Agent
#
# ![{07ACA78A-BB89-410D-9A51-203FB292B5FF}.png](attachment:7fcc6d12-4721-4c55-a1fe-760f85037b01.png)

# %% [markdown]
# ## Add an Ai Agent Workflow Node
#
# ![{3EF42DE2-3A5C-405C-9591-3806E2659571}.png](attachment:01c8feb5-f31b-44e6-88b9-42ef94dd361a.png)
#
# #### You will get this agent
#
# ![{A9651C01-2470-4529-AFB8-0112DCEBC017}.png](attachment:38b0135a-3140-4a9c-a443-7728e8390d37.png)
#
# #### You have to add
#
# #### 1. An LLM
# #### 2. A memory
# #### 3. Tools (Here we will use MCP Clients)
#
# #### So, click on + of the Chat Model component, you can choose to use ollama locally or add credentials to call models like ChatGPT, DeepSeek, Gemini, Claude ...
#
# #### NB : In ollama you have to select a model suporting tools call (gemma family do not, you have to work around prompt template to make it tools compatible)
#
# ![{33C35F5F-3998-426F-824E-DE9610489BAA}.png](attachment:34fcbeef-7a9c-4388-9fcb-6f5ca89414cf.png)
#
# #### For memory just select a simple memory node
#
# ![{4616E3D1-799C-4C05-A296-29B3015292E1}.png](attachment:2807b5f7-0d5a-447d-bf3d-cd83361ce507.png)
#
#
# #### For tools you can use the native MCP Client node. It support SSE url servers
# #### Or install the MCP Client community node (just go to settings)
#
# ![{79126887-A405-4F36-BD97-3864C04AA52B}.png](attachment:514ea44e-0782-4487-869e-5a20178929e9.png)
#
#
# #### Now you can select either the native or the community MCP Client
#
# ![{E931823D-69F0-4238-855E-5FF3E8090372}.png](attachment:d38a9f18-68ea-45d4-b706-b3b1c60320fc.png)

# %% [markdown]
# #### Use of the n8n native MCP Client
# #### test with our MCP Web Server (Be sur to run the fast api application with uv uvicorn, see command below)
#
# ![{E6B9B64D-75E8-4A26-8AAD-F7D4CBBFD489}.png](attachment:b403cfd2-7458-43c1-b980-03f4fa2069d2.png)
#
# ####

# %% [markdown]
# #### Here is a sample using DeepSeek endpoint and our mcp sse server to navigate and return datat from a wwebsite
#
# ![{5EFDA0C3-8C85-49C2-A197-3BEFDAEB5581}.png](attachment:d7ff4599-802a-4219-a2c8-369aa5e9a0ea.png)

# %% [markdown]
# #### For local MCP Servers like our python-executor STDIO we will use the commuunity node
# ####
# ![{5697BA4D-B06F-46BB-9967-1CE2394ED70C}.png](attachment:d3705c3b-f699-4cb0-b4e5-cc193247534a.png)
#
# #### Create a new credential
#
# ![{39EE918D-E486-4AD4-A3AE-4FFAF991F222}.png](attachment:d81fb28e-5814-4041-b01c-a47016b8f345.png)
#
# #### Then choose list_tools (you can test bu click test step)
#
# ![{E86979BE-6E04-4FBE-91F6-F991209D1E87}.png](attachment:928bcad3-b5a8-4e7d-bfe1-1b36ee2b4b7b.png)
#
# #### then add the same node with executetool
#
# ![{3A7D698F-EB51-43D0-9A0B-F18E4481E7A2}.png](attachment:3376a22e-8f17-4286-ac86-d2ea57e3e5d1.png)
#
# #### You can select "Defined automaticaly" by the model for the args

# %% [markdown]
# #### Test with a simple prompt asking the agent to run a python code to get system date and time
# #### Here with Claude as LLM backbone
#
# ![{1B1DA309-4084-48A9-9FB7-78A70FA553DE}.png](attachment:85b1ee7f-c93e-4878-8611-5cb67d59b191.png)
