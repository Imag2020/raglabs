# %% [markdown]
# # <span style="color:orange">  7. Exercice : Building a NotebookLM Webapp with n8n , mcp , and loveable </span>

# %% [markdown]
# ## Objective  :
#
# Build a clone of the most powerfull RAG Web Application (we are in 2025/07 ! ) : notebooklm.google
#
# ![{E8571A40-69ED-4098-B34B-C97D9F37611D}.png](attachment:aa2cfea7-1849-49e7-9478-ae89b5667b57.png)
#
#
# ## Architecture :
#
# #### Backend :
#
# ##### FastApi
# ##### n8n
#
# #### Frontend
#
# ##### gradio
# or
# ##### React/Vite
#
#
# ## Tools :
#
# ##### GEMINI-CLI
# ##### VS + Cline
# ##### Loveable

# %% [markdown]
# #### <span style="color:magenta"> Solution in a youtube video soon <span>
